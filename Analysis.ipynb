# %%
import pandas as pd
import numpy as np

# %%
energy = pd.read_excel("EnergyConsumption.xls", sheet_name="Energy")
direct = pd.read_excel("EnergyConsumption.xls", sheet_name="Direct_Use")
reallocate = pd.read_excel("EnergyConsumption.xls", sheet_name="Reallocated")
totals = pd.read_excel("EnergyConsumption.xls", sheet_name="Total_Use")

# %%
energy = energy.T
direct = direct.T
reallocate = reallocate.T
totals = totals.T

# %%
energy.head()
# Out:
#                                                                      0   \
# Million tonnes of oil equivalent  Energy from renewable & waste sources
# 1990                                                              1.501
# 1991                                                              1.517
# 1992                                                              1.682
# 1993                                                              1.762
#
#                                                    1                   2   \
# Million tonnes of oil equivalent  Hydroelectric power  Wind, wave, tidal1
# 1990                                            0.448               0.001
# 1991                                            0.398               0.001
# 1992                                            0.467               0.003
# 1993                                             0.37               0.019
#
#                                                   3                    4   \
# ...

# %%
direct.head()
# Out:
#                                                                                  0   \
# Million tonnes of oil equivalent  Direct3 use of energy from renewable & waste s...
# 1990                                                                          1.501
# 1991                                                                          1.517
# 1992                                                                          1.682
# 1993                                                                          1.762
#
#                                                                  1   \
# Million tonnes of oil equivalent  Agriculture, forestry and fishing
# 1990                                                          0.013
# 1991                                                          0.012
# 1992                                                          0.013
# 1993                                                          0.012
#
# ...

# %%
reallocate.head()
# Out:
#                                                                                  0   \
# Million tonnes of oil equivalent  Reallocated3 use of energy from renewable & wa...
# 1990                                                                          1.501
# 1991                                                                          1.517
# 1992                                                                          1.682
# 1993                                                                          1.762
#
#                                                                                  1   \
# Million tonnes of oil equivalent  Energy industry electricity transformation los...
# 1990                                                                            NaN
# 1991                                                                            NaN
# 1992                                                                            NaN
# ...

# %%
totals.head()
# Out:
#                                                                         0  \
# Million tonnes of oil equivalent  Energy from renewable sources and waste
# 1990                                                                1.501
# 1991                                                                1.517
# 1992                                                                1.682
# 1993                                                                1.762
#
#                                                                                   1  \
# Million tonnes of oil equivalent  Total energy consumption of primary fuels and ...
# 1990                                                                         224.63
# 1991                                                                        230.603
# 1992                                                                        227.925
# 1993                                                                        230.564
#
# ...
